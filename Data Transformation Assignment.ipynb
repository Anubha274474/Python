# %%
                                                   # Data Transformation Assignment

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('employee_productivity_dataset.csv')
df.head()
# Out:
#   Employee_ID         Name Department   Age  Gender Work_Mode   Join_Date  \
# 0        E001  Amit Sharma         IT  25.0    Male    Remote  15-01-2021
# 1        E002   Riya Patel         HR  30.0  Female    Hybrid  15-02-2020
# 2        E003  John Mathew    Finance   NaN    Male    Onsite  10-03-2022
# 3        E004  Sneha Joshi         IT  28.0  Female    Remote  22-04-2021
# 4        E005  Arjun Verma  Marketing  35.0    Male    Hybrid  18-05-2020
#
#    Hours_Worked_Per_Week  Projects_Completed  Performance_Score   Salary  \
# 0                   40.0                   5                4.5  50000.0
# 1                   38.0                   4                4.0  45000.0
# 2                   45.0                   6                NaN  60000.0
# 3                    NaN                   5                4.2  52000.0
# 4                   50.0                   7                4.8      NaN
#
#     Location
# 0       Pune
# 1     Mumbai
# 2  Bangalore
# 3      Delhi
# ...

# %%
#Question 1:- Handele Missing Values(Basic Cleaning)
# Fill missing values using the following:
# Age -> Median
# Salary-> Mean
# Hours_Worked_Score-> Mean
# Performance_Score-> Mean
# Display the datast after handeling missing values.

# %%
df.columns
# Out:
# Index(['Employee_ID', 'Name', 'Department', 'Age', 'Gender', 'Work_Mode',
#        'Join_Date', 'Hours_Worked_Per_Week', 'Projects_Completed',
#        'Performance_Score', 'Salary', 'Location'],
#       dtype='object')

# %%
df['Hours_Worked_Per_Week']
# Out:
# 0      40.0
# 1      38.0
# 2      45.0
# 3       NaN
# 4      50.0
#        ...
# 245    36.0
# 246    48.0
# 247    42.0
# 248     NaN
# 249    37.0
# Name: Hours_Worked_Per_Week, Length: 250, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            250 non-null    object
#  1   Name                   250 non-null    object
#  2   Department             250 non-null    object
#  3   Age                    225 non-null    float64
#  4   Gender                 250 non-null    object
#  5   Work_Mode              250 non-null    object
#  6   Join_Date              250 non-null    object
#  7   Hours_Worked_Per_Week  200 non-null    float64
#  8   Projects_Completed     250 non-null    int64
#  9   Performance_Score      200 non-null    float64
#  10  Salary                 225 non-null    float64
#  11  Location               250 non-null    object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 23.6+ KB

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(25)

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df['Salary']=df['Salary'].fillna(df['Salary'].mean())

# %%
df['Hours_Worked_Per_Week']=df['Hours_Worked_Per_Week'].fillna(df['Hours_Worked_Per_Week'].median())

# %%
df['Performance_Score']=df['Performance_Score'].fillna(df['Performance_Score'].mean())

# %%
df
# Out:
#     Employee_ID         Name Department   Age  Gender Work_Mode   Join_Date  \
# 0          E001  Amit Sharma         IT  25.0    Male    Remote  15-01-2021
# 1          E002   Riya Patel         HR  30.0  Female    Hybrid  15-02-2020
# 2          E003  John Mathew    Finance  29.0    Male    Onsite  10-03-2022
# 3          E004  Sneha Joshi         IT  28.0  Female    Remote  22-04-2021
# 4          E005  Arjun Verma  Marketing  35.0    Male    Hybrid  18-05-2020
# ..          ...          ...        ...   ...     ...       ...         ...
# 245        E006   Neha Singh         HR  27.0  Female    Remote  01-06-2023
# 246        E007    Rahul Das    Finance  40.0    Male    Onsite  07-07-2019
# 247        E008  Pooja Mehta  Marketing  29.0  Female    Hybrid  12-08-2022
# 248        E009  Sameer Khan         IT  31.0    Male    Remote  30-09-2021
# 249        E010   Kiran Nair         HR  26.0  Female    Onsite  05-10-2023
#
# ...

# %%
df.isnull().sum()
# Out:
# Employee_ID              0
# Name                     0
# Department               0
# Age                      0
# Gender                   0
# Work_Mode                0
# Join_Date                0
# Hours_Worked_Per_Week    0
# Projects_Completed       0
# Performance_Score        0
# Salary                   0
# Location                 0
# dtype: int64

# %%
# Question 2:- Label Handeling
# Convert these columns into columns into numeric values using Label Encoding:
# Gender
# Department
# Show the updated columns.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df['Department']=le.fit_transform(df['Department'])

# %%
df[['Gender','Department']]
# Out:
#      Gender  Department
# 0         1           2
# 1         0           1
# 2         1           0
# 3         0           2
# 4         1           3
# ..      ...         ...
# 245       0           1
# 246       1           0
# 247       0           3
# 248       1           2
# 249       0           1
#
# [250 rows x 2 columns]

# %%
df
# Out:
#     Employee_ID         Name  Department   Age  Gender Work_Mode   Join_Date  \
# 0          E001  Amit Sharma           2  25.0       1    Remote  15-01-2021
# 1          E002   Riya Patel           1  30.0       0    Hybrid  15-02-2020
# 2          E003  John Mathew           0  29.0       1    Onsite  10-03-2022
# 3          E004  Sneha Joshi           2  28.0       0    Remote  22-04-2021
# 4          E005  Arjun Verma           3  35.0       1    Hybrid  18-05-2020
# ..          ...          ...         ...   ...     ...       ...         ...
# 245        E006   Neha Singh           1  27.0       0    Remote  01-06-2023
# 246        E007    Rahul Das           0  40.0       1    Onsite  07-07-2019
# 247        E008  Pooja Mehta           3  29.0       0    Hybrid  12-08-2022
# 248        E009  Sameer Khan           2  31.0       1    Remote  30-09-2021
# 249        E010   Kiran Nair           1  26.0       0    Onsite  05-10-2023
#
# ...

# %%
# Question 3:- One-Hot Encoding
# Apply One-Hot Encoding on:
# Work Mode
# Location
# Display the dtaset and check how many columns are created

# %%
df=pd.get_dummies (df,columns=['Work_Mode'],drop_first=True)

# %%
df=pd.get_dummies(df,columns=['Location'],drop_first=True)

# %%
df
# Out:
#     Employee_ID         Name Department   Age  Gender   Join_Date  \
# 0          E001  Amit Sharma         IT  25.0    Male  15-01-2021
# 1          E002   Riya Patel         HR  30.0  Female  15-02-2020
# 2          E003  John Mathew    Finance   NaN    Male  10-03-2022
# 3          E004  Sneha Joshi         IT  28.0  Female  22-04-2021
# 4          E005  Arjun Verma  Marketing  35.0    Male  18-05-2020
# ..          ...          ...        ...   ...     ...         ...
# 245        E006   Neha Singh         HR  27.0  Female  01-06-2023
# 246        E007    Rahul Das    Finance  40.0    Male  07-07-2019
# 247        E008  Pooja Mehta  Marketing  29.0  Female  12-08-2022
# 248        E009  Sameer Khan         IT  31.0    Male  30-09-2021
# 249        E010   Kiran Nair         HR  26.0  Female  05-10-2023
#
#      Hours_Worked_Per_Week  Projects_Completed  Performance_Score   Salary  \
# 0                     40.0                   5                4.5  50000.0
# ...

# %%
# Question 4:-Normalisation (Min-Max_Scaling)
# Normalize the following columns:
# Salary
# Hours_Worked_Per_Week
# Use MinMaxScaler and display results.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler_mm = MinMaxScaler()
df[['Salary_norm','Hours_Worked_norm']]=scaler_mm.fit_transform(
    df[['Salary','Hours_Worked_Per_Week']]
)

# %%
print(df[['Salary','Salary_norm','Hours_Worked_Per_Week','Hours_Worked_norm']].head())
# Out:
#     Salary  Salary_norm  Hours_Worked_Per_Week  Hours_Worked_norm
# 0  50000.0     0.347826                   40.0           0.285714
# 1  45000.0     0.130435                   38.0           0.142857
# 2  60000.0     0.782609                   45.0           0.642857
# 3  52000.0     0.434783                    NaN                NaN
# 4      NaN          NaN                   50.0           1.000000

# %%
# Question 5:- Standardization (Scaling)
# Apply StandardScaler on:
# Age
# Projects_Completed
# Display the transformed values.

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler_std=StandardScaler()
df[['Age_std','Projects_Completed_std']]=scaler_std.fit_transform(
    df[['Age','Projects_Completed']]
)

# %%
print(df[['Age','Age_std','Projects_Completed','Projects_Completed_std']].head())
# Out:
#     Age   Age_std  Projects_Completed  Projects_Completed_std
# 0  25.0 -1.140068                   5               -0.211604
# 1  30.0 -0.024784                   4               -0.916949
# 2   NaN       NaN                   6                0.493742
# 3  28.0 -0.470898                   5               -0.211604
# 4  35.0  1.090500                   7                1.199088

# %%
# Question 6:-Compare Scaling Methods
# Apply both:
# MinMaxScaler
# StandardScaler
# On the Salary Column.
# Show both results side by side

# %%
df_temp=df[['Salary']].copy()

mm_scaler=MinMaxScaler()
std_scaler=StandardScaler()

df_temp['Salary_MinMax']=mm_scaler.fit_transform(df_temp[['Salary']])
df_temp['Salary_Standard']=std_scaler.fit_transform(df_temp[['Salary']])

# %%
print(df_temp.head())
# Out:
#     Salary  Salary_MinMax  Salary_Standard
# 0  50000.0       0.347826        -0.092450
# 1  45000.0       0.130435        -0.785825
# 2  60000.0       0.782609         1.294300
# 3  52000.0       0.434783         0.184900
# 4      NaN            NaN              NaN

# %%
# Question 7:-Build Preprocessing Pipeline
# Create a pipeline that:
# Applies encoding to categorical columns
# Applies scaling to numerical columns
# Use:
# ColumnTransformer
# Pipeline

# %%
# Reloading original df to avoid interference from Q2-Q6

# %%
df=pd.read_csv('employee_productivity_dataset.csv')

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import OneHotEncoder

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.7.2

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
# Define column pipeline: impute + scale

numeric_transform = Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())
 ])

# %%
num_cols=['Age','Salary','Hours_Worked_Per_Week','Projects_Completed','Performance_Score']
cat_cols=['Gender','Departemnt','Work_Mode','Location']

# %%
# WE WILL CHECK THE THE NUMERICAL COLUMNS AS WELL AS CATEGORICAL COLUMNS

# %%
print('Numrical_Columns',num_cols)
print('Categorical_Columns',cat_cols)
# Out:
# Numrical_Columns ['Age', 'Salary', 'Hours_Worked_Per_Week', 'Projects_Completed', 'Performance_Score']
# Categorical_Columns ['Gender', 'Departemnt', 'Work_Mode', 'Location']

# %%
# Create a pipeline for numeric columns
# Handel missing values with median.then standardize.

# %%
numeric_transformer=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='medium')),
    ('scaler',StandardScaler())
])

# %%
# Create a pipeline for categorical columns
# Handel missing values with most frequent,then one-hot encode.drop='first' avoids dummy vaiable trap.

# %%
categorical_transformer=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequently')),
    ('onehot',OneHotEncoder(drop='first',handle_unknown='ignore'))
])

# %%
# Combine them with ColumnTransformer
# the full processing pipeline.

# %%
from sklearn.compose import ColumnTransformer

# %%
preprocessor=ColumnTransformer(
    transformers=[
        ('num',numeric_transformer,num_cols),
        ('cat',categorical_transformer,cat_cols)
    ]
)

# %%
# Question 8:- Apply Pipeline
# Apply the pipeline on the dataset
# Display:
# Transformed dataset
# Shape of final dataset

# %%
# Apply the Pipline to the Dataset
# Fit and transform the data
# fit_transform learns the imputation means/ medians,scaling parameters,and categories from your data
# then applies the transformations.

# %%
import pandas as pd

# %%
df=pd.read_csv('employee_productivity_dataset.csv')
df.head()
# Out:
#   Employee_ID         Name Department   Age  Gender Work_Mode   Join_Date  \
# 0        E001  Amit Sharma         IT  25.0    Male    Remote  15-01-2021
# 1        E002   Riya Patel         HR  30.0  Female    Hybrid  15-02-2020
# 2        E003  John Mathew    Finance   NaN    Male    Onsite  10-03-2022
# 3        E004  Sneha Joshi         IT  28.0  Female    Remote  22-04-2021
# 4        E005  Arjun Verma  Marketing  35.0    Male    Hybrid  18-05-2020
#
#    Hours_Worked_Per_Week  Projects_Completed  Performance_Score   Salary  \
# 0                   40.0                   5                4.5  50000.0
# 1                   38.0                   4                4.0  45000.0
# 2                   45.0                   6                NaN  60000.0
# 3                    NaN                   5                4.2  52000.0
# 4                   50.0                   7                4.8      NaN
#
#     Location
# 0       Pune
# 1     Mumbai
# 2  Bangalore
# 3      Delhi
# ...

# %%
# define sub-pipelines

numeric_transformer=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',StandardScaler())
])

categorical_transformer=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('onehot',OneHotEncoder(drop='first',sparse_output=False,handle_unknown='ignore'))
])

# %%
# Combine them
from sklearn.compose import ColumnTransformer
preprocessor= ColumnTransformer(
    transformers=[
        ('num',numeric_transformer,num_cols),
        ('cat',categorical_transformer,cat_cols)
    ]
)

# %%
# this line is what makes fir_transformer work

pipeline=Pipeline(steps=[('preprocessor',preprocessor)])

# %%
print(type(pipeline))
print(pipeline)
# Out:
# <class 'sklearn.pipeline.Pipeline'>
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Salary',
#                                                    'Hours_Worked_Per_Week',
#                                                    'Projects_Completed',
#                                                    'Performance_Score']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
# ...

# %%
df
# Out:
#     Employee_ID         Name Department   Age  Gender Work_Mode   Join_Date  \
# 0          E001  Amit Sharma         IT  25.0    Male    Remote  15-01-2021
# 1          E002   Riya Patel         HR  30.0  Female    Hybrid  15-02-2020
# 2          E003  John Mathew    Finance   NaN    Male    Onsite  10-03-2022
# 3          E004  Sneha Joshi         IT  28.0  Female    Remote  22-04-2021
# 4          E005  Arjun Verma  Marketing  35.0    Male    Hybrid  18-05-2020
# ..          ...          ...        ...   ...     ...       ...         ...
# 245        E006   Neha Singh         HR  27.0  Female    Remote  01-06-2023
# 246        E007    Rahul Das    Finance  40.0    Male    Onsite  07-07-2019
# 247        E008  Pooja Mehta  Marketing  29.0  Female    Hybrid  12-08-2022
# 248        E009  Sameer Khan         IT  31.0    Male    Remote  30-09-2021
# 249        E010   Kiran Nair         HR  26.0  Female    Onsite  05-10-2023
#
# ...

# %%
# Question 9:- Conceptual Question:-
# Why scaling is important in python?

# %%
# Scaling is important because:

 1. Many ML algorithems like KNN , SVM ,Neural Network , and Gradient Descent are sensitive to feature magnitude. 

 A feature with range 1000-50000 will dominate a feature with 0-1.

 2. Scaling helps moels coverage faster during training.

 3. It ensures all features contribute equally to distance calculations and loss functions.

 4. Without caling,coefficient in linear models become hard to interpret.

# %%
# Question 10:- Conceptual Question
# Why do we convert categorical data into numerical form?

# %%
# A: ML Models work only with numbers. Converting Categorical data to numerical form allows:

1 Algorithms to performs mathematical operations and find patterns.
    
2 Label Encoding for ordinal data where order matters,e.g, Low=0,Medium-1,High=2.

3 One-Hot Encoding for nominal data where no order exists,e.g,Color,Country. This avoids creating false ordinal relationships.

4 Models like Logistic Regression, SVM, and Neural Networks require numerical input.
